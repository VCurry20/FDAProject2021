# %%
import numpy as np                      # import NumPy - standard abbreviatation np
import matplotlib.pyplot as plt         # import matplotlib.pyplot - standard abbreviatation plt

# %%
# Make a random dataset:
height = [10, 20, 30, 40, 50]        # set the height data
bars = ('A', 'B', 'C', 'D', 'E')     # set the names of the bars
y_pos = np.arange(len(bars))         #


plt.bar(y_pos, height)               # plot barplot

plt.xticks(y_pos, bars)              # Create names on the x-axis

#plt.show()                           # Show graphic
# Out:
# ([<matplotlib.axis.XTick at 0x2930fc3a1c0>,
# ...
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E')])

# %%
rng = np.random.default_rng(19680801)                             # set random generator

# Compute pie slices
N = 20                                                            # Number - 20 
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)            # Angle
radii = 10 * rng.random(N)                                        # radius
width = np.pi / 4 * rng.random(N)                                 # Width
colors = plt.cm.hsv(radii / 10.)                              # Colours

ax = plt.subplot(projection='polar')                                      # axis - projection - polar
ax.bar(theta, radii, width=width, bottom=0.0, color=colors, alpha=0.5)    # set the bars

#plt.show()
# Out:
# <BarContainer object of 20 artists>

# %%
import math

# %%
ax = plt.subplot(projection='polar')              

ax.barh(0, math.radians(250))
ax.barh(1, math.radians(240))
ax.barh(2, math.radians(180))
ax.barh(3, math.radians(300))

ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)                      # clockwise / anticlock wise <-1 clockwise
ax.set_rlabel_position(0)
ax.set_thetagrids([0, 96, 192, 288], labels=[0, 20, 40, 60])
ax.set_rgrids([0, 1, 2, 3], labels=['a', 'b', 'c', 'd'])

# plt.show()
# Out:
# (<a list of 4 Line2D gridline objects>,
#  [Text(0, 0, 'a'), Text(0, 1, 'b'), Text(0, 2, 'c'), Text(0, 3, 'd')])
